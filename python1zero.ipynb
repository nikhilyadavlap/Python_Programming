# %% [markdown]
# Question 1: Add two numbers

# %%
a = 10
b = 20

print(a + b)
# Out:
# 30

# %% [markdown]
# Question 2: Print Hello

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# Question 3: Check Python Version

# %%
# !python --version
# Out:
# Python 3.14.6

# %% [markdown]
# Question 4: Print Name

# %%
name = "Eliot"
print("Hello", name)
# Out:
# Hello Eliot

# %% [markdown]
# Question 5:  Type

# %%
x = 10
print(type(x))
# Out:
# <class 'int'>

# %%
name = "Eliot"
print(type(name))
# Out:
# <class 'str'>

# %% [markdown]
# Question 6: Variable

# %%
age = 20
print(age)
# Out:
# 20

# %% [markdown]
# Question 7:First mini program

# %%
name = "Eliot"
age = 20

print(name)
print(age)
print(type(name))
print(type(age))
# Out:
# Eliot
# 20
# <class 'str'>
# <class 'int'>

# %% [markdown]
# Question 8: Experiment

# %%
data = 100
print(data)
print(type(data))

data = "Python"
print(data)
print(type(data))
# Out:
# 100
# <class 'int'>
# Python
# <class 'str'>
