# %% [markdown]
# Question 1: Store and print personal information.
#
# Problem
#
# Create four variables to store:
# - Your name
# - Your age
# - Your height
# - Whether you are a student
#
# print all the values.

# %%
name = "Eliot"
age = 23
height = 5.9
is_student = True

print(name)
print(age)
print(height)
print(is_student)
# Out:
# Eliot
# 23
# 5.9
# True

# %% [markdown]
# Question 2: Add Two Numbers
#
# Problem
#
# Create two variables and print their sum.

# %%
num1 = 25
num2 = 15

sum = num1 + num2

print(sum)
# Out:
# 40

# %% [markdown]
# Question 3: Perform Basic Arithmetic Operations
#
# Problem
#
# Create two variables and perform:
#
# - Addition
# - Subtraction
# - Multiplication
# - Division

# %%
a = 20
b = 5

print("Addition =", a + b)
print("Subtraction =", a - b)
print("Multiplication =", a * b)
print("Divisin =", a / b)
# Out:
# Addition = 25
# Subtraction = 15
# Multiplication = 100
# Divisin = 4.0

# %% [markdown]
# Qestion 4: Find the Remainder
#
# Problem
#
# Create two variables and print the remainder using the modulus operator (%).

# %%
a = 23
b = 4

print(a % b)
# Out:
# 3

# %% [markdown]
# Question 5: Compare two numbers
#
# Problem
#
# Create two variables and print the results of:
#
# - Greater than(>)
# - Less than(<)
# - Equal to(==)
# - Not equat to(!=)

# %%
a = 12
b = 20

print(a > b)
print(a < b)
print(a == b)
print(a != b)
# Out:
# False
# True
# False
# True

# %% [markdown]
# Question 6: Find the Data Type
#
# Problem
#
# Create variables of different data types and print their types using type().

# %%
number = 100
price = 99.99
language = "Python"
status = True

print(type(number))
print(type(price))
print(type(language))
print(type(status))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# Question 7: Swap two variables
#
# Problem
#
# Swap the values of two variables without using a third variable.

# %%
a = 10
b = 50

a , b = b , a 

print(a)
print(b)
# Out:
# 50
# 10

# %% [markdown]
# Question 8: Calculate the square and cube.
#
# Problem
#
# Create a variable and print its square and cube.

# %%
number = 4

print("Square =", number ** 2)
print("Cube =", number ** 3)
# Out:
# Square = 16
# Cube = 64

# %% [markdown]
# Question 9: Take user input and print it.
#
# Problem
#
# Take the user's name as input and print a welcome message.

# %%
name = input("Enter your name: ")

print("Welcome, ", name)
# Out:
# Welcome,  Eliot

# %% [markdown]
# Question 10: Add two numbers using uer input
#
# Problem
#
# Take two numbers from the user add print their sum.

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

print("Sum =", num1 + num2)
# Out:
# Sum = 44
